# %%
import pandas as pd
import numpy as np

# %%
# Read in Patient Info
# Read in the california housing data set
PatientInfo_data = pd.read_csv('../Data/sg/PatientInfo.csv')
PatientInfo_data.head()
# Out:
#    patient_id  global_num     sex  birth_year  age country province  \
# 0  1000000001         2.0    male      1964.0  50s   Korea    Seoul
# 1  1000000002         5.0    male      1987.0  30s   Korea    Seoul
# 2  1000000003         6.0    male      1964.0  50s   Korea    Seoul
# 3  1000000004         7.0    male      1991.0  20s   Korea    Seoul
# 4  1000000005         9.0  female      1992.0  20s   Korea    Seoul
#
#           city disease        infection_case  infection_order   infected_by  \
# 0   Gangseo-gu     NaN       overseas inflow              1.0           NaN
# 1  Jungnang-gu     NaN       overseas inflow              1.0           NaN
# 2    Jongno-gu     NaN  contact with patient              2.0  2.002000e+09
# 3      Mapo-gu     NaN       overseas inflow              1.0           NaN
# 4  Seongbuk-gu     NaN  contact with patient              2.0  1.000000e+09
#
#    contact_number symptom_onset_date confirmed_date released_date  \
# 0            75.0         2020-01-22     2020-01-23    2020-02-05
# 1            31.0                NaN     2020-01-30    2020-03-02
# 2            17.0                NaN     2020-01-30    2020-02-19
# 3             9.0         2020-01-26     2020-01-30    2020-02-15
# 4             2.0                NaN     2020-01-31    2020-02-24
#
#   deceased_date     state
# 0           NaN  released
# 1           NaN  released
# 2           NaN  released
# 3           NaN  released
# 4           NaN  released

# %%
Case_data =pd.read_csv('../Data/sg/Case.csv')
Case_data.head()
# Out:
#    case_id province           city  group                 infection_case  \
# 0  1000001    Seoul        Guro-gu   True            Guro-gu Call Center
# 1  1000002    Seoul  Dongdaemun-gu   True                  Dongan Church
# 2  1000003    Seoul   Eunpyeong-gu   True  Eunpyeong St. Mary's Hospital
# 3  1000004    Seoul   Seongdong-gu   True               Seongdong-gu APT
# 4  1000005    Seoul      Jongno-gu   True        Jongno Community Center
#
#    confirmed   latitude   longitude
# 0         79  37.508163  126.884387
# 1         24  37.592888  127.056766
# 2         14   37.63369    126.9165
# 3         13   37.55713    127.0403
# 4         10   37.57681     127.006

# %%
TimeGender_data = pd.read_csv('../Data/sg/Case.csv')
condition_True = (TimeGender_data["group"]==True)
TimeGender_data[condition_True]
count_True = len(TimeGender_data[condition_True])
print(count_True)


condition_False = (TimeGender_data["group"]==False)
TimeGender_data[condition_False]
count_False = len((TimeGender_data[condition_False]))
print(count_False)

TimeGender_data.head()
# Out:
# 51
# 30
#    case_id province           city  group                 infection_case  \
# 0  1000001    Seoul        Guro-gu   True            Guro-gu Call Center
# 1  1000002    Seoul  Dongdaemun-gu   True                  Dongan Church
# 2  1000003    Seoul   Eunpyeong-gu   True  Eunpyeong St. Mary's Hospital
# 3  1000004    Seoul   Seongdong-gu   True               Seongdong-gu APT
# 4  1000005    Seoul      Jongno-gu   True        Jongno Community Center
#
#    confirmed   latitude   longitude
# 0         79  37.508163  126.884387
# 1         24  37.592888  127.056766
# 2         14   37.63369    126.9165
# 3         13   37.55713    127.0403
# 4         10   37.57681     127.006

# %%
len(PatientInfo_data)
# Out:
# 2243

# %% [markdown]
# ## Gender

# %%
condition_deceased = (PatientInfo_data["state"]=="deceased")

condition_male = (PatientInfo_data["sex"]=="male")

condition_both = condition_deceased & condition_male
print("Male")
print(len(PatientInfo_data[condition_male]))
print(len(PatientInfo_data[condition_both]))


condition_female = (PatientInfo_data["sex"]=="female")
condition_both2 = condition_deceased & condition_female
print("Female")
print(len(PatientInfo_data[condition_female]))
print(len(PatientInfo_data[condition_both2]))
# Out:
# Male
# 937
# 22
# Female
# 1210
# 9

# %% [markdown]
# ## Convert to Date

# %% [markdown]
# ##    Days: Released Date MINUS Confirmed Date

# %%
PatientInfo_data.dtypes
# Out:
# patient_id              int64
# global_num            float64
# sex                    object
# birth_year            float64
# age                    object
# country                object
# province               object
# city                   object
# disease                object
# infection_case         object
# infection_order       float64
# infected_by           float64
# contact_number        float64
# symptom_onset_date     object
# confirmed_date         object
# released_date          object
# deceased_date          object
# state                  object
# dtype: object

# %%
# Changing format 
PatientInfo_data["Date IN"]= pd.to_datetime(PatientInfo_data["confirmed_date"])

# %%
# Changing format 
PatientInfo_data["Date OUT"]= pd.to_datetime(PatientInfo_data["released_date"])

# %%
# Changing format 
PatientInfo_data["Date Symptoms"]= pd.to_datetime(PatientInfo_data["symptom_onset_date"])

# %%
PatientInfo_data["Days"] = PatientInfo_data["Date OUT"] - PatientInfo_data["Date IN"]

# %%
PatientInfo_data["Days"].mean()
# Out:
# Timedelta('13 days 22:52:01.030042')

# %% [markdown]
# ## Age is a Number

# %%
PatientInfo_data["age"]
# Out:
# 0       50s
# 1       30s
# 2       50s
# 3       20s
# 4       20s
#        ...
# 2238    30s
# 2239    20s
# 2240    20s
# 2241    40s
# 2242    40s
# Name: age, Length: 2243, dtype: object

# %%
Age = []
PatientInfo_data["age"].fillna("-1s", inplace = True)

ages = PatientInfo_data["age"]  
BeforeSymbol = PatientInfo_data["age"].str.split('s').str[0]
BeforeSymbol
for age in BeforeSymbol:
        Age.append(int(age))
        
Age

PatientInfo_data["Age"] = Age

# %%
PatientInfo_data.head()
# Out:
#    patient_id  global_num     sex  birth_year  age country province  \
# 0  1000000001         2.0    male      1964.0  50s   Korea    Seoul
# 1  1000000002         5.0    male      1987.0  30s   Korea    Seoul
# 2  1000000003         6.0    male      1964.0  50s   Korea    Seoul
# 3  1000000004         7.0    male      1991.0  20s   Korea    Seoul
# 4  1000000005         9.0  female      1992.0  20s   Korea    Seoul
#
#           city disease        infection_case  ...  symptom_onset_date  \
# 0   Gangseo-gu     NaN       overseas inflow  ...          2020-01-22
# 1  Jungnang-gu     NaN       overseas inflow  ...                 NaN
# 2    Jongno-gu     NaN  contact with patient  ...                 NaN
# 3      Mapo-gu     NaN       overseas inflow  ...          2020-01-26
# 4  Seongbuk-gu     NaN  contact with patient  ...                 NaN
#
#    confirmed_date  released_date deceased_date     state Age    Date IN  \
# 0      2020-01-23     2020-02-05           NaN  released  50 2020-01-23
# 1      2020-01-30     2020-03-02           NaN  released  30 2020-01-30
# 2      2020-01-30     2020-02-19           NaN  released  50 2020-01-30
# 3      2020-01-30     2020-02-15           NaN  released  20 2020-01-30
# 4      2020-01-31     2020-02-24           NaN  released  20 2020-01-31
#
#     Date OUT  Date Symptoms    Days
# 0 2020-02-05     2020-01-22 13 days
# 1 2020-03-02            NaT 32 days
# 2 2020-02-19            NaT 20 days
# 3 2020-02-15     2020-01-26 16 days
# 4 2020-02-24            NaT 24 days
#
# [5 rows x 23 columns]

# %% [markdown]
# ## Examine: Contact Number and State "Deceased"

# %%
PatientInfo_data["contact_number"]
# Out:
# 0       75.0
# 1       31.0
# 2       17.0
# 3        9.0
# 4        2.0
#         ...
# 2238     NaN
# 2239    87.0
# 2240    84.0
# 2241    21.0
# 2242    74.0
# Name: contact_number, Length: 2243, dtype: float64

# %% [markdown]
# ## Column contact_number represents how many contacts the Patient had.

# %%
Max_contact = PatientInfo_data["contact_number"].max()

super_max = Max_contact + 1


Max_contact
Max=int(Max_contact)
Max
# Out:
# 1160

# %%
PatientInfo_data["contact_number"].mean()
# Out:
# 24.019370460048425

# %%
unique_number = PatientInfo_data["contact_number"].unique()
unique_number
len(unique_number)
# Out:
# 73

# %%
unique_number[0]
# Out:
# 75.0

# %%
len(unique_number)
check_point = len(unique_number)

# %% [markdown]
# ## Study: Relationship of Deceased with Contact Number

# %%
condition_deceased = (PatientInfo_data["state"]=="deceased")

# %%
PatientInfo_deceased = PatientInfo_data[condition_deceased]

# %%
total_deceased = len(PatientInfo_deceased)
total_deceased
# Out:
# 32

# %%
PatientInfo_deceased["contact_number"]
# Out:
# 405    NaN
# 444    NaN
# 445    NaN
# 446    NaN
# 447    NaN
# 448    NaN
# 449    NaN
# 450    NaN
# 451    NaN
# 452    NaN
# 453    NaN
# 454    NaN
# 455    NaN
# 456    NaN
# 457    NaN
# 458    NaN
# 459    NaN
# 460    NaN
# 461    NaN
# 462    NaN
# 652    NaN
# 942    NaN
# 1636   NaN
# 1935   NaN
# 1971   NaN
# 2049   NaN
# 2050   NaN
# 2051   NaN
# 2052   NaN
# 2053   NaN
# 2054   NaN
# 2055   NaN
# Name: contact_number, dtype: float64

# %%
PatientInfo_data["state"].unique()
# Out:
# array(['released', 'isolated', 'deceased', nan], dtype=object)

# %%
condition_released = (PatientInfo_data["state"]=="released")
PatientInfo_released = PatientInfo_data[condition_released]

# %%
PatientInfo_released["contact_number"]
# Out:
# 0       75.0
# 1       31.0
# 2       17.0
# 3        9.0
# 4        2.0
#         ...
# 2233     NaN
# 2235     NaN
# 2236     NaN
# 2240    84.0
# 2241    21.0
# Name: contact_number, Length: 314, dtype: float64

# %%
PatientInfo_released["Age"].mean()
# Out:
# 34.15923566878981

# %%
PatientInfo_released["Age"].min()
# Out:
# -1

# %%
PatientInfo_released["Age"].max()
# Out:
# 80

# %%
number_deceased = []

# %%
n=0
condition = ((PatientInfo_data["contact_number"] == unique_number[n]))
condition_study = condition_deceased & condition
number_deceased.append(len(PatientInfo_data[condition_study]))

PatientInfo_data[condition_study]
# Out:
# Empty DataFrame
# Columns: [patient_id, global_num, sex, birth_year, age, country, province, city, disease, infection_case, infection_order, infected_by, contact_number, symptom_onset_date, confirmed_date, released_date, deceased_date, state, Date IN, Date OUT, Date Symptoms, Days, Age]
# Index: []
#
# [0 rows x 23 columns]

# %%
for n in range(check_point):
    condition = ((PatientInfo_data["contact_number"] == unique_number[n]))
    condition_study = condition_deceased & condition
    number_deceased.append(len(PatientInfo_data[condition_study]))

# %%
if_contact_number = 10

# %%
condition = (PatientInfo_data["contact_number"] >= if_contact_number)
then_deceased = len(PatientInfo_data[condition])
print("If contact number is :" + str(if_contact_number))
print("Then deceased is :"+str(then_deceased))
      
PatientInfo_data[condition]
# Out:
# If contact number is :10
# Then deceased is :149
#       patient_id  global_num     sex  birth_year  age country  \
# 0     1000000001         2.0    male      1964.0  50s   Korea
# 1     1000000002         5.0    male      1987.0  30s   Korea
# 2     1000000003         6.0    male      1964.0  50s   Korea
# 5     1000000006        10.0  female      1966.0  50s   Korea
# 8     1000000009        19.0    male      1983.0  30s   Korea
# ...          ...         ...     ...         ...  ...     ...
# 1896  6014000001         NaN  female      1959.0  60s   Korea
# 2239  7000000001       139.0    male      1998.0  20s   Korea
# 2240  7000000002       222.0  female      1998.0  20s   Korea
# 2241  7000000003      4345.0  female      1972.0  40s   Korea
# 2242  7000000004      5534.0    male      1974.0  40s   Korea
#
#               province         city disease        infection_case  ...  \
# 0                Seoul   Gangseo-gu     NaN       overseas inflow  ...
# 1                Seoul  Jungnang-gu     NaN       overseas inflow  ...
# 2                Seoul    Jongno-gu     NaN  contact with patient  ...
# 5                Seoul    Jongno-gu     NaN  contact with patient  ...
# 8                Seoul    Songpa-gu     NaN       overseas inflow  ...
# ...                ...          ...     ...                   ...  ...
# 1896  Gyeongsangbuk-do   Yeongju-si     NaN                   NaN  ...
# 2239           Jeju-do      Jeju-do     NaN                   etc  ...
# 2240           Jeju-do      Jeju-do     NaN                   etc  ...
# 2241           Jeju-do          etc     NaN                   etc  ...
# 2242           Jeju-do      Jeju-do     NaN                   etc  ...
#
#       symptom_onset_date  confirmed_date  released_date deceased_date  \
# 0             2020-01-22      2020-01-23     2020-02-05           NaN
# 1                    NaN      2020-01-30     2020-03-02           NaN
# 2                    NaN      2020-01-30     2020-02-19           NaN
# 5                    NaN      2020-01-31     2020-02-19           NaN
# 8                    NaN      2020-02-05     2020-02-21           NaN
# ...                  ...             ...            ...           ...
# 1896                 NaN      2020-02-22            NaN           NaN
# 2239                 NaN      2020-02-20            NaN           NaN
# 2240                 NaN      2020-02-22     2020-03-07           NaN
# 2241                 NaN      2020-03-02     2020-03-15           NaN
# 2242                 NaN      2020-03-04            NaN           NaN
#
#          state    Date IN   Date OUT Date Symptoms    Days Age
# 0     released 2020-01-23 2020-02-05    2020-01-22 13 days  50
# 1     released 2020-01-30 2020-03-02           NaT 32 days  30
# 2     released 2020-01-30 2020-02-19           NaT 20 days  50
# 5     released 2020-01-31 2020-02-19           NaT 19 days  50
# 8     released 2020-02-05 2020-02-21           NaT 16 days  30
# ...        ...        ...        ...           ...     ...  ..
# 1896  isolated 2020-02-22        NaT           NaT     NaT  60
# 2239  isolated 2020-02-20        NaT           NaT     NaT  20
# 2240  released 2020-02-22 2020-03-07           NaT 14 days  20
# 2241  released 2020-03-02 2020-03-15           NaT 13 days  40
# 2242  isolated 2020-03-04        NaT           NaT     NaT  40
#
# [149 rows x 23 columns]

# %%
Avg_contact = PatientInfo_data["contact_number"].mean()
Avg_contact
# Out:
# 24.019370460048425

# %%
Max_contact = PatientInfo_data["contact_number"].max()

condition_max = PatientInfo_data["contact_number"]==Max_contact
PatientInfo_data[condition_max]
# Out:
#      patient_id  global_num     sex  birth_year  age country province city  \
# 400  1200000031        31.0  female      1959.0  60s   Korea    Daegu  NaN
#
#     disease      infection_case  ...  symptom_onset_date  confirmed_date  \
# 400     NaN  Shincheonji Church  ...                 NaN      2020-02-18
#
#      released_date deceased_date     state    Date IN Date OUT Date Symptoms  \
# 400            NaN           NaN  isolated 2020-02-18      NaT           NaT
#
#     Days Age
# 400  NaT  60
#
# [1 rows x 23 columns]

# %%
Min_contact = PatientInfo_data["contact_number"].min()

# %%
condition_zero = (PatientInfo_data["contact_number"]> 0)

# %% [markdown]
# Condition contact_number is non zero

# %%
condition_nonZero = PatientInfo_data["contact_number"]> 0
PatientInfo_data[condition_nonZero]
# Out:
#       patient_id  global_num     sex  birth_year  age country  \
# 0     1000000001         2.0    male      1964.0  50s   Korea
# 1     1000000002         5.0    male      1987.0  30s   Korea
# 2     1000000003         6.0    male      1964.0  50s   Korea
# 3     1000000004         7.0    male      1991.0  20s   Korea
# 4     1000000005         9.0  female      1992.0  20s   Korea
# ...          ...         ...     ...         ...  ...     ...
# 1897  6014000002         NaN    male      1998.0  20s   Korea
# 2239  7000000001       139.0    male      1998.0  20s   Korea
# 2240  7000000002       222.0  female      1998.0  20s   Korea
# 2241  7000000003      4345.0  female      1972.0  40s   Korea
# 2242  7000000004      5534.0    male      1974.0  40s   Korea
#
#               province         city disease        infection_case  ...  \
# 0                Seoul   Gangseo-gu     NaN       overseas inflow  ...
# 1                Seoul  Jungnang-gu     NaN       overseas inflow  ...
# 2                Seoul    Jongno-gu     NaN  contact with patient  ...
# 3                Seoul      Mapo-gu     NaN       overseas inflow  ...
# 4                Seoul  Seongbuk-gu     NaN  contact with patient  ...
# ...                ...          ...     ...                   ...  ...
# 1897  Gyeongsangbuk-do   Yeongju-si     NaN                   NaN  ...
# 2239           Jeju-do      Jeju-do     NaN                   etc  ...
# 2240           Jeju-do      Jeju-do     NaN                   etc  ...
# 2241           Jeju-do          etc     NaN                   etc  ...
# 2242           Jeju-do      Jeju-do     NaN                   etc  ...
#
#       symptom_onset_date  confirmed_date  released_date deceased_date  \
# 0             2020-01-22      2020-01-23     2020-02-05           NaN
# 1                    NaN      2020-01-30     2020-03-02           NaN
# 2                    NaN      2020-01-30     2020-02-19           NaN
# 3             2020-01-26      2020-01-30     2020-02-15           NaN
# 4                    NaN      2020-01-31     2020-02-24           NaN
# ...                  ...             ...            ...           ...
# 1897                 NaN      2020-02-24            NaN           NaN
# 2239                 NaN      2020-02-20            NaN           NaN
# 2240                 NaN      2020-02-22     2020-03-07           NaN
# 2241                 NaN      2020-03-02     2020-03-15           NaN
# 2242                 NaN      2020-03-04            NaN           NaN
#
#          state    Date IN   Date OUT Date Symptoms    Days Age
# 0     released 2020-01-23 2020-02-05    2020-01-22 13 days  50
# 1     released 2020-01-30 2020-03-02           NaT 32 days  30
# 2     released 2020-01-30 2020-02-19           NaT 20 days  50
# 3     released 2020-01-30 2020-02-15    2020-01-26 16 days  20
# 4     released 2020-01-31 2020-02-24           NaT 24 days  20
# ...        ...        ...        ...           ...     ...  ..
# 1897  isolated 2020-02-24        NaT           NaT     NaT  20
# 2239  isolated 2020-02-20        NaT           NaT     NaT  20
# 2240  released 2020-02-22 2020-03-07           NaT 14 days  20
# 2241  released 2020-03-02 2020-03-15           NaT 13 days  40
# 2242  isolated 2020-03-04        NaT           NaT     NaT  40
#
# [364 rows x 23 columns]

# %%
condition_deceased = (PatientInfo_data["state"]=="deceased")
PatientInfo_data[condition_deceased]
len(PatientInfo_data[condition_deceased])
# Out:
# 32

# %%
ages = PatientInfo_data[condition_deceased]["age"]  


BeforeSymbol = PatientInfo_data[condition_deceased]["age"].str.split('s').str[0]


    
BeforeSymbol
age_list = []

for ages in BeforeSymbol:
    if pd.notna(ages):
        age_list.append(int(ages))
    
age_list
sum = 0
for age in age_list:
    sum = sum + age
    
total = len(age_list)
print(total)
mean = 0
mean = sum/total
mean
avg_age_deceased = mean
avg_age_deceased
# Out:
# 32
# 62.46875

# %%
condition_both = condition_nonZero & condition_deceased

# %%
len(PatientInfo_data[condition_both])
# Out:
# 0

# %%
condition_both = condition_zero & condition_deceased
len(PatientInfo_data[condition_both])
# Out:
# 0

# %% [markdown]
# ## Patient MADE it

# %%
condition_alive = (PatientInfo_data["state"]!="deceased")

# %%
PatientInfo_data[condition_alive]
# Out:
#       patient_id  global_num     sex  birth_year  age country  \
# 0     1000000001         2.0    male      1964.0  50s   Korea
# 1     1000000002         5.0    male      1987.0  30s   Korea
# 2     1000000003         6.0    male      1964.0  50s   Korea
# 3     1000000004         7.0    male      1991.0  20s   Korea
# 4     1000000005         9.0  female      1992.0  20s   Korea
# ...          ...         ...     ...         ...  ...     ...
# 2238  6100000085         NaN    male      1990.0  30s   Korea
# 2239  7000000001       139.0    male      1998.0  20s   Korea
# 2240  7000000002       222.0  female      1998.0  20s   Korea
# 2241  7000000003      4345.0  female      1972.0  40s   Korea
# 2242  7000000004      5534.0    male      1974.0  40s   Korea
#
#               province         city disease        infection_case  ...  \
# 0                Seoul   Gangseo-gu     NaN       overseas inflow  ...
# 1                Seoul  Jungnang-gu     NaN       overseas inflow  ...
# 2                Seoul    Jongno-gu     NaN  contact with patient  ...
# 3                Seoul      Mapo-gu     NaN       overseas inflow  ...
# 4                Seoul  Seongbuk-gu     NaN  contact with patient  ...
# ...                ...          ...     ...                   ...  ...
# 2238  Gyeongsangnam-do  Changwon-si     NaN                   NaN  ...
# 2239           Jeju-do      Jeju-do     NaN                   etc  ...
# 2240           Jeju-do      Jeju-do     NaN                   etc  ...
# 2241           Jeju-do          etc     NaN                   etc  ...
# 2242           Jeju-do      Jeju-do     NaN                   etc  ...
#
#       symptom_onset_date  confirmed_date  released_date deceased_date  \
# 0             2020-01-22      2020-01-23     2020-02-05           NaN
# 1                    NaN      2020-01-30     2020-03-02           NaN
# 2                    NaN      2020-01-30     2020-02-19           NaN
# 3             2020-01-26      2020-01-30     2020-02-15           NaN
# 4                    NaN      2020-01-31     2020-02-24           NaN
# ...                  ...             ...            ...           ...
# 2238                 NaN      2020-03-16            NaN           NaN
# 2239                 NaN      2020-02-20            NaN           NaN
# 2240                 NaN      2020-02-22     2020-03-07           NaN
# 2241                 NaN      2020-03-02     2020-03-15           NaN
# 2242                 NaN      2020-03-04            NaN           NaN
#
#          state    Date IN   Date OUT Date Symptoms    Days Age
# 0     released 2020-01-23 2020-02-05    2020-01-22 13 days  50
# 1     released 2020-01-30 2020-03-02           NaT 32 days  30
# 2     released 2020-01-30 2020-02-19           NaT 20 days  50
# 3     released 2020-01-30 2020-02-15    2020-01-26 16 days  20
# 4     released 2020-01-31 2020-02-24           NaT 24 days  20
# ...        ...        ...        ...           ...     ...  ..
# 2238       NaN 2020-03-16        NaT           NaT     NaT  30
# 2239  isolated 2020-02-20        NaT           NaT     NaT  20
# 2240  released 2020-02-22 2020-03-07           NaT 14 days  20
# 2241  released 2020-03-02 2020-03-15           NaT 13 days  40
# 2242  isolated 2020-03-04        NaT           NaT     NaT  40
#
# [2211 rows x 23 columns]

# %%
alive = len(PatientInfo_data[condition_alive])
alive
# Out:
# 2211

# %%
ages_alive = PatientInfo_data[condition_alive]["age"]  


BeforeSymbol = PatientInfo_data[condition_alive]["age"].str.split('s').str[0]


    
BeforeSymbol
age_alive = []

for ages in BeforeSymbol:
    if pd.notna(ages):
        age_alive.append(int(ages))
    
age_alive
sum = 0
for age in age_alive:
    sum = sum + age
    
total = len(age_alive)
print(total)
mean = 0
mean = sum/total
mean

# How many made it alive about the age : avg_age_deceased ?
# Out:
# 2211
# 35.365445499773855

# %% [markdown]
# ## How many Alive above the Average Age Deceased

# %%
count = 0

for age in age_alive:
    if (age >= avg_age_deceased):
        count = count + 1
        
print(count)
# Out:
# 205

# %%
#Examined the age of the Patient's that were not deceased and looked at 
# how many were above the average age of the deceased 62

#Days hospitalized
#Update This file

#Age and Contact_Number
#Bar by Male/Female
#All Female
#All Male
